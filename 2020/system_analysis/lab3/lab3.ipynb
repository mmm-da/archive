# %%
import random
import math
import numpy
import scipy.integrate as integrate
import scipy.optimize as optimize
import matplotlib.pyplot as pyplot

sz = 11
sg = 0.5
k = 5
def fx(x):
    return math.exp(math.sin(x))+x

def gx(i, x):
    return math.sin(i+1 * x)


def zx(x, func):
    res = 0
    for i in range(0, k):
        res += a[i] * func(i, x)
    return res

if __name__ == "__main__":
    y_t = []
    v = []
    y = []
    K = []
    x = []
    Z = []
    for i in range (0, sz):
        y_t.append(fx(i + 1))
        x.append(i + 1)        
        K.append(numpy.zeros(sz))
        K[i][i] = sg * (i + 1) * 0.1
        if (random.randint(0, 1)):
            y.append(y_t[i] + K[i][i])
        else:
            y.append(y_t[i] - K[i][i])

    F = numpy.zeros((sz, k))
    for j in range(0, sz):
        for i in range(0, k):
            F[j][i] = gx(i, x[j])

    a = numpy.linalg.inv(F.transpose().dot(K).dot(F)).dot(F.transpose().dot(K).dot(y))
    print(a)
    for i in x:
        Z.append(zx(i, gx))
    
    print("F(4.5) = ", fx(4.5))
    print("Z(4.5) = ", zx(4.5, gx))
    print("F(9) = ", fx(9.5))
    print("Z(9) = ", zx(9.5, gx))

    pyplot.scatter(x, y)
    pyplot.scatter(x, y_t)
    pyplot.plot(x, Z)
    pyplot.show()
# Out:
# [-2. 16. -8.  8. -4.]
# F(4.5) =  4.876239218806267
# Z(4.5) =  -6.74449351479465
# F(9) =  10.427603295897546
# Z(9) =  -10.666925406131764

# %%
import random
import math
import numpy
import scipy.integrate as integrate
import scipy.optimize as optimize
import matplotlib.pyplot as pyplot

sz = 11
sg = 0.5
k = 6
def fx(x):
    return math.sin(x)

def gx(i, x):
    return math.sin(i+1 * x)


def zx(x, func):
    res = 0
    for i in range(0, k):
        res += a[i] * func(i, x)
    return res

if __name__ == "__main__":
    y_t = []
    v = []
    y = []
    K = []
    x = []
    Z = []
    for i in range (0, sz):
        y_t.append(fx(i + 1))
        x.append(i + 1)        
        K.append(numpy.zeros(sz))
        K[i][i] = sg * (i + 1) * 0.1
        if (random.randint(0, 1)):
            y.append(y_t[i] + K[i][i])
        else:
            y.append(y_t[i] - K[i][i])

    F = numpy.zeros((sz, k))
    for j in range(0, sz):
        for i in range(0, k):
            F[j][i] = gx(i, x[j])

    a = numpy.linalg.inv(F.transpose().dot(K).dot(F)).dot(F.transpose().dot(K).dot(y))
    print(a)
    for i in x:
        Z.append(zx(i, gx))
    
    print("F(4.5) = ", fx(4.5))
    print("Z(4.5) = ", zx(4.5, gx))
    print("F(9) = ", fx(9.5))
    print("Z(9) = ", zx(9.5, gx))

    pyplot.scatter(x, y)
    pyplot.scatter(x, y_t)
    pyplot.plot(x, Z)
    pyplot.show()
# Out:
# [-0.625    1.       0.      -2.       0.34375 -0.25   ]
# F(4.5) =  -0.977530117665097
# Z(4.5) =  -1.6773162304994071
# F(9) =  -0.0751511204618093
# Z(9) =  -0.6575053822346889
